# %%
from data.processing import ParseAll

subset_name = "autotagging_top50tags"
subset_file = f"./mtgjamendodataset/data/{subset_name}.tsv"
data_directory = "E:/mtg-jamendo/"
output_directory = f"D:/SongsDataset/melspec-mtg-jamendo"
subset_data = f'./mtgjamendodataset/stats/{subset_name}/all.tsv'

ParseAll(subset_file, subset_data, data_directory, output_directory)
# Out:
# Reading: 54380 tracks, 11107 albums, 3517 artists
# Processing tracks...
#  15%|█▌        | 8346/54380 [05:55<15:14:14,  1.19s/it]

# %%
from utils.Config import Config
from data.data_utils import *
from torch.utils.data import DataLoader
from utils import misc
from models.Myna import Myna
from training.contrastive_training import train_contrastive

model_name = "Myna-CLS-ROPE-TEMPO-TEST"
config = Config(
        save_path=f"trained_models\\{model_name}\\",
        num_epochs=64,
        learning_rate=3e-4,
        weight_decay=1e-4,
        num_workers=3,
        batch_size=32,
        dtype=torch.float32
    )

chunk_size = 256

train_dataset = StreamViewDataset(f"D:\\SongsDataset\\melspec-mtg-jamendo\\train_set\\", chunk_size=chunk_size)
test_dataset  = StreamViewDataset(f"D:\\SongsDataset\\melspec-mtg-jamendo\\test_set\\", chunk_size=chunk_size)

prefetch_factor = 1
train_dataloader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=config.num_workers,
    prefetch_factor=prefetch_factor,
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=config.num_workers,
    prefetch_factor=prefetch_factor,
)

model = Myna(
    image_size=(128, chunk_size),
    channels=1,
    patch_size=(16, 16),
    latent_space=128,
    d_model=384,
    depth=12,
    heads=6,
    mlp_dim=1536,
    mask_ratio=0.75,
    use_cls=True,
    predict_tempo="CNN",
    use_sinusoidal=False,
    use_y_emb=True,
    use_rope_x=True,
    use_rope_y=False,
    rope_base=128,
    use_alibi_x=False,
    use_alibi_y=False
    #clamping=AttentionClamping(method="cap", cap_type="tanh", cap_value=16, learnable=False)
)
# Out:
# Reading: 54380 tracks, 11107 albums, 3517 artists
# Reading: 54380 tracks, 11107 albums, 3517 artists

# %%
print(f"{misc.model_size(model)} Parameters")
train_contrastive(model, test_dataloader, train_dataloader, config, start_epoch=0, views=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"{misc.model_size(model)} Parameters")
#       2 train_contrastive(model, test_dataloader, train_dataloader, config, start_epoch=0, views=2)
#
# NameError: name 'misc' is not defined

# %%
from huggingface_hub import hf_hub_download
import torch

model_path = hf_hub_download(
    repo_id="m-a-a-p/RPECL",
    filename="first_training_set/1d_alibi_Epoch-511.pt"
)
print("Downloaded checkpoint to:", model_path)
# Out:
# Downloaded checkpoint to: C:\Users\Potat\.cache\huggingface\hub\models--m-a-a-p--RPECL\snapshots\fc8bc535ee7435450e6fcb3cc7a4a716a0ca3559\first_training_set\1d_alibi_Epoch-511.pt

# %%
from utils.Config import Config
from data.data_utils import *
from torch.utils.data import DataLoader
from utils import misc
from models.Myna import Myna
from training.contrastive_training import train_contrastive

model_name = "Myna-CLS-Album-Artist"
config = Config(
        save_path=f"trained_models\\{model_name}\\",
        num_epochs=128,
        learning_rate=3e-4,
        weight_decay=1e-4,
        num_workers=4,
        batch_size=32,
        dtype=torch.float32
    )

# %%
chunk_size = 256

train_dataset = StreamViewDataset(f"D:\\SongsDataset\\melspec-mtg-jamendo\\train_set\\", chunk_size=chunk_size, views=3, playlist=True)
test_dataset  = StreamViewDataset(f"D:\\SongsDataset\\melspec-mtg-jamendo\\test_set\\", chunk_size=chunk_size, views=3, playlist=True)

prefetch_factor = 2
train_dataloader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=config.num_workers,
    prefetch_factor=prefetch_factor,
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=config.batch_size,
    shuffle=True,
    num_workers=config.num_workers,
    prefetch_factor=prefetch_factor,
)
# Out:
# Reading: 54380 tracks, 11107 albums, 3517 artists
# Reading: 54380 tracks, 11107 albums, 3517 artists

# %%
import torch
from models.Myna import Myna

chunk_size = 256

model = Myna(image_size=(128, chunk_size),
    channels=1,
    patch_size=(16, 16),
    latent_space=128,
    d_model=384,
    depth=12,
    heads=6,
    mlp_dim=1536,
    mask_ratio=0.75,
    use_cls=True,
    use_sinusoidal=False,
    use_y_emb=True,
    use_rope_x=False,
    use_rope_y=False,
    rope_base=False,
    use_alibi_x=True,
    use_alibi_y=False)

model.load_state_dict(torch.load(model_path, map_location=config.device, weights_only=False))
model.to(config.device)
model.mask_ratio = 0.75
model.eval()
# Out:
# Myna(
#   (to_patch_embedding): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=16, p2=16)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(in_features=256, out_features=384, bias=True)
#     (3): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (alibi_2d): Alibi2DBias()
#     (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (layers): ModuleList(
#       (0-11): 12 x ModuleList(
#         (0): Attention(
#           (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attend): Softmax(dim=-1)
#           (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#           (to_out): Linear(in_features=384, out_features=384, bias=False)
#         )
#         (1): FeedForward(
#           (net): Sequential(
#             (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
# ...

# %%
print(f"{misc.model_size(model)} Parameters")
train_contrastive(model, test_dataloader, train_dataloader, config, start_epoch=0, views=3)
# Out:
# 21428608 Parameters
# ...
#   0%|          | 0/84 [00:42<?, ?it/s]
# [Epoch 0] Train: Same Song Contrastive Loss = 2.4614
# Test: Same Song Contrastive Loss = 1.9234
# ...
#   0%|          | 0/84 [00:41<?, ?it/s]
# [Epoch 1] Train: Same Song Contrastive Loss = 2.4494
# Test: Same Song Contrastive Loss = 1.8985
# ...
#   0%|          | 0/84 [00:40<?, ?it/s]
# [Epoch 2] Train: Same Song Contrastive Loss = 2.4401
# Test: Same Song Contrastive Loss = 1.9013
# ...
#   0%|          | 0/84 [00:45<?, ?it/s]
# [Epoch 3] Train: Same Song Contrastive Loss = 2.4386
# Test: Same Song Contrastive Loss = 1.9545
# ...
#   0%|          | 0/84 [00:42<?, ?it/s]
# [Epoch 4] Train: Same Song Contrastive Loss = 2.4216
# Test: Same Song Contrastive Loss = 1.9280
# ...
#   0%|          | 0/84 [00:47<?, ?it/s]
# [Epoch 5] Train: Same Song Contrastive Loss = 2.4122
# Test: Same Song Contrastive Loss = 1.9273
# ...
#   0%|          | 0/84 [00:42<?, ?it/s]
# [Epoch 6] Train: Same Song Contrastive Loss = 2.4001
# ...
